# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(value=df['Age'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df['Embarked'].fillna(method='ffill',inplace=True)

# %%
df.drop(['Name','Ticket','PassengerId'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  22.0      1      0    7.2500        S
# 1           1       1  female  38.0      1      0   71.2833        C
# 2           1       3  female  26.0      0      0    7.9250        S
# 3           1       1  female  35.0      1      0   53.1000        S
# 4           0       3    male  35.0      0      0    8.0500        S
# 5           0       3    male   NaN      0      0    8.4583        Q
# 6           0       1    male  54.0      0      0   51.8625        S
# 7           0       3    male   2.0      3      1   21.0750        S
# 8           1       3  female  27.0      0      2   11.1333        S
# 9           1       2  female  14.0      1      0   30.0708        C
# 10          1       3  female   4.0      1      1   16.7000        S
# 11          1       1  female  58.0      0      0   26.5500        S
# 12          0       3    male  20.0      0      0    8.0500        S
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Sex']=le.fit_transform(df['Sex'])

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    1  22.0      1      0    7.2500        S
# 1           1       1    0  38.0      1      0   71.2833        C
# 2           1       3    0  26.0      0      0    7.9250        S
# 3           1       1    0  35.0      1      0   53.1000        S
# 4           0       3    1  35.0      0      0    8.0500        S
# 5           0       3    1   NaN      0      0    8.4583        Q
# 6           0       1    1  54.0      0      0   51.8625        S
# 7           0       3    1   2.0      3      1   21.0750        S
# 8           1       3    0  27.0      0      2   11.1333        S
# 9           1       2    0  14.0      1      0   30.0708        C
# 10          1       3    0   4.0      1      1   16.7000        S
# 11          1       1    0  58.0      0      0   26.5500        S
# 12          0       3    1  20.0      0      0    8.0500        S
# ...

# %%
status=pd.get_dummies(df['Embarked'])

# %%
status.head()
# Out:
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1

# %%
status=pd.get_dummies(df['Embarked'],drop_first=True)

# %%
status.head()
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
df1=pd.concat([df,status],axis=1)

# %%
df1.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Q  S
# 0         0       3    1  22.0      1      0   7.2500        S  0  1
# 1         1       1    0  38.0      1      0  71.2833        C  0  0
# 2         1       3    0  26.0      0      0   7.9250        S  0  1
# 3         1       1    0  35.0      1      0  53.1000        S  0  1
# 4         0       3    1  35.0      0      0   8.0500        S  0  1

# %%
df1.drop('Embarked',axis=1,inplace=True)

# %%
df1
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Q  S
# 0           0       3    1  22.0      1      0    7.2500  0  1
# 1           1       1    0  38.0      1      0   71.2833  0  0
# 2           1       3    0  26.0      0      0    7.9250  0  1
# 3           1       1    0  35.0      1      0   53.1000  0  1
# 4           0       3    1  35.0      0      0    8.0500  0  1
# 5           0       3    1   NaN      0      0    8.4583  1  0
# 6           0       1    1  54.0      0      0   51.8625  0  1
# 7           0       3    1   2.0      3      1   21.0750  0  1
# 8           1       3    0  27.0      0      2   11.1333  0  1
# 9           1       2    0  14.0      1      0   30.0708  0  0
# 10          1       3    0   4.0      1      1   16.7000  0  1
# 11          1       1    0  58.0      0      0   26.5500  0  1
# 12          0       3    1  20.0      0      0    8.0500  0  1
# 13          0       3    1  39.0      1      5   31.2750  0  1
# ...

# %%
df1['Age'].fillna(value=df1['Age'].mean(),inplace=True)

# %%
x_train=x_train[(x_train['Fare']>(np.mean(x_train['Fare'])-3*np.std(x_train['Fare']))) & (x_train['Fare']<(np.mean(x_train['Fare'])+3*np.std(x_train['Fare'])))]
df3.shape

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Q           0
# S           0
# dtype: int64

# %%
df1_cont.describe(percentiles=[0.015,0.99,0.25,0.75,0.5])
# Out:
#               Age        Fare
# count  891.000000  891.000000
# mean    29.699118   32.204208
# std     13.002015   49.693429
# min      0.420000    0.000000
# 1.5%     1.350000    0.000000
# 25%     22.000000    7.910400
# 50%     29.699118   14.454200
# 75%     35.000000   31.000000
# 99%     65.000000  249.006220
# max     80.000000  512.329200

# %%
df1['Age']=df1_cont[df1_cont['Age']<=65]

# %%
df1['Fare']=df1_cont[df1_cont['Fare']<=249]

# %%
x=df1.drop('Survived',axis=1)
y=df1.Survived

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,train_size=0.7,random_state=100)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train[['Age','Fare']]=scaler.fit_transform(x_train[['Age','Fare']]) ## fit transform is done only for the cantinous data not for the discrete data

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
from sklearn.feature_selection import RFE

# %%
rfe=RFE(lr,6)

# %%
rfe=rfe.fit(x_train,y_train)

# %%
list(zip(x_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('Pclass', True, 1),
#  ('Sex', True, 1),
#  ('Age', True, 1),
#  ('SibSp', True, 1),
#  ('Parch', True, 1),
#  ('Fare', True, 1),
#  ('Q', False, 3),
#  ('S', False, 2)]

# %%
sel_col=x_train.columns[rfe.support_]   #here x_train is already scaled and i have not renamed it thats all

# %%
x_train_rfe=x_train[sel_col]

# %%
lr.fit(x_train_rfe,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_lr_train=lr.predict(x_train_rfe) # predicting the value for y

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print(' Accuracy Score:\n')
print(accuracy_score(y_train,y_pred_lr_train))  # here we are getting 95% accuracy
# Out:
#  Accuracy Score:
#
# 0.8170144462279294

# %%
print('confusion matrix:\n\n',classification_report(y_train,y_pred_lr_train))
# Out:
# confusion matrix:
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       390
#            1       0.79      0.70      0.74       233
#
#     accuracy                           0.82       623
#    macro avg       0.81      0.79      0.80       623
# weighted avg       0.82      0.82      0.81       623

# %%
x_test[['Age','Fare']]=scaler.transform(x_test[['Age','Fare']]) ## fit transform is done only for the cantinous data not for the discrete data

# %%
x_test_rfe=x_test[x_train_rfe.columns]

# %%
y_pred_lr_test=lr.predict(x_test_rfe) # predicting the value for y

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print(' Accuracy Score:\n')
print(accuracy_score(y_test,y_pred_lr_test))  # here we are getting 95% accuracy
# Out:
#  Accuracy Score:
#
# 0.7611940298507462

# %%
print('confusion matrix:\n\n',classification_report(y_test,y_pred_lr_test))
# Out:
# confusion matrix:
#
#                precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79       159
#            1       0.69      0.75      0.72       109
#
#     accuracy                           0.76       268
#    macro avg       0.75      0.76      0.76       268
# weighted avg       0.77      0.76      0.76       268

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Q           0
# S           0
# dtype: int64

# %%
df1['Age'].fillna(value=df1['Age'].mean(),inplace=True)

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Q           0
# S           0
# dtype: int64

# %%
df1['Fare'].fillna(value=df1['Fare'].mean(),inplace=True)

# %%
x_train.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# SibSp     0
# Parch     0
# Fare      0
# Q         0
# S         0
# dtype: int64

# %%
x_train['Fare'].fillna(value=x_train['Fare'].mean(),inplace=True)

# %%
x_train['Age'].fillna(value=x_train['Age'].mean(),inplace=True)

# %%
x_test['Fare'].fillna(value=x_test['Fare'].mean(),inplace=True)

# %%
x_test['Age'].fillna(value=x_test['Age'].mean(),inplace=True)

# %%
x_test.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# SibSp     0
# Parch     0
# Fare      0
# Q         0
# S         0
# dtype: int64

# %%
import statsmodels.api as sm

# %%
x_train_rfe_sm=sm.add_constant(x_train_rfe)

# %%
lgmod=sm.GLM(y_train,x_train_rfe_sm,family=sm.families.Binomial()).fit()

# %%
print(lgmod.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  623
# Model:                            GLM   Df Residuals:                      616
# Model Family:                Binomial   Df Model:                            6
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -269.97
# Date:                Thu, 12 Sep 2019   Deviance:                       539.94
# Time:                        11:46:47   Pearson chi2:                     648.
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.8978      0.445      8.760      0.000       3.026       4.770
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor #check for the VIF values of the feauture variables

# %%
vif=pd.DataFrame()
vif['Features']=x_train_rfe_sm.columns
vif['VIF']=[variance_inflation_factor(x_train_rfe_sm.values,i) for i in range(x_train_rfe_sm.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#   Features    VIF
# 0    const  14.04
# 1   Pclass   1.61
# 6     Fare   1.53
# 5    Parch   1.34
# 4    SibSp   1.31
# 3      Age   1.20
# 2      Sex   1.09

# %%
y_train_sm_pred=lgmod.predict(x_train_rfe_sm) ### we  should not find the r2_score bcs this is logistics

# %%
len(y_train)
# Out:
# 623

# %%
len(y_train_sm_pred)
# Out:
# 623

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print(' Accuracy Score:\n')
print(accuracy_score(y_train,y_train_sm_pred.round()))
# Out:
#  Accuracy Score:
#
# 0.8154093097913323

# %%
print('confusion matrix:\n\n',classification_report(y_train,y_train_sm_pred.round()))
# Out:
# confusion matrix:
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86       390
#            1       0.78      0.71      0.74       233
#
#     accuracy                           0.82       623
#    macro avg       0.81      0.79      0.80       623
# weighted avg       0.81      0.82      0.81       623

# %%
x_test_rfe_sm=sm.add_constant(x_test_rfe)

# %%
lgmod1=sm.GLM(y_test,x_test_rfe_sm,family=sm.families.Binomial()).fit()

# %%
print(lgmod1.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  268
# Model:                            GLM   Df Residuals:                      261
# Model Family:                Binomial   Df Model:                            6
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -121.99
# Date:                Thu, 12 Sep 2019   Deviance:                       243.98
# Time:                        11:47:27   Pearson chi2:                     261.
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -10.8972      8.740     -1.247      0.212     -28.027       6.232
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor #check for the VIF values of the feauture variables

# %%
vif=pd.DataFrame()
vif['Features']=x_test_rfe_sm.columns
vif['VIF']=[variance_inflation_factor(x_test_rfe_sm.values,i) for i in range(x_test_rfe_sm.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#   Features      VIF
# 0    const  2633.15
# 1   Pclass     1.91
# 6     Fare     1.87
# 5    Parch     1.27
# 4    SibSp     1.25
# 3      Age     1.22
# 2      Sex     1.15

# %%
y_test_sm_pred=lgmod.predict(x_test_rfe_sm) ### we  should not find the r2_score bcs this is logistics

# %%
len(y_test)
# Out:
# 268

# %%
len(y_test_sm_pred)
# Out:
# 268

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print(' Accuracy Score:\n')
print(accuracy_score(y_test,y_test_sm_pred.round()))
# Out:
#  Accuracy Score:
#
# 0.7686567164179104

# %%
print('confusion matrix:\n\n',classification_report(y_test,y_test_sm_pred.round()))
# Out:
# confusion matrix:
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.76      0.80       159
#            1       0.69      0.78      0.73       109
#
#     accuracy                           0.77       268
#    macro avg       0.76      0.77      0.76       268
# weighted avg       0.78      0.77      0.77       268

# %%
x_train.skew()
# Out:
# Pclass   -0.590515
# Sex      -0.616077
# Age       0.429725
# SibSp     3.599042
# Parch     2.580332
# Fare      5.116991
# Q         2.981692
# S        -1.059079
# dtype: float64

# %%
sns.boxplot(x_train['Fare'])

# %%
sns.boxplot(x_train['Parch'])

# %%
x_train=x_train[(x_train['Fare']>(np.mean(x_train['Fare'])-0.5*np.std(x_train['Fare']))) & (x_train['Fare']<(np.mean(x_train['Fare'])+1.5*np.std(x_train['Fare'])))]
x_train.shape
# Out:
# (52, 8)
